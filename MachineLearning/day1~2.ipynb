# %% [markdown]
# # 머신러닝
#
# ![image.png](attachment:image.png)
#
# 인공지능 - 사고나 학습 등 인간이 가진 지적 능력을 컴퓨터를 통해 구현하는 기술
# 머신러닝 - 컴퓨터가 스스로 학습하여 인공지능의 성능을 향상 시키는 기술 방법
# 딥러닝 - 인간의 뉴런과 비슷한 인공신경망 방식으로 정보를 처리하는 방식
#
# - 데이터를 기반으로 학습을 시켜서 예측하게 만드는 기법
# - 인공지능의 한 분야로 컴퓨터가 학습할 수 있도록 하는 알고리즘 기술을 개발하는 분야
# - 통계학, 데이터 마이닝, 컴퓨터 과학이 어우러진 분야
#
#
#
# - 약한인공지능
#     특정 분야를 위해 제작된 인공지능
# - 강한인공지능
#     모든 방면에서 인간급의 인공지능
#     사고, 계획, 문제해결, 추상화, 복잡한 개념 학습
# - 초인공지능
#     모든 영역에서 인간보다 뛰어남
#
# 규칙 기반 전문가 시스템
#  - 많은 상황에 대한 규칙들을 모두 만들 수 없음
#  - 규칙을 설계하려면 분야에 대해서 잘 알아야함
#
#
# 머신러닝
#
# 데이터를 이용하여 스스로 특성과 패턴을 찾아 학습하고 예측을 수행하는 것
# ![image-2.png](attachment:image-2.png)
#
#
#  머신러닝 종류
#
#   - 지도학습 (Supervised Learning)
#   - 비지도학습 (Unsupervised Learning)
#   - 강화학습 (Reinforcement Learning)
#
#
#
#
#   ### 지도학습
#   - 데이터에 대한 Label(명시적인 답)이 주어진 상태에서 컴퓨터를 학습시키는 방법
#   - 분류(Classification)(범주형)와 회귀(Regression)(연속형 데이터) 방법이 존재
#
#   ![image-3.png](attachment:image-3.png)
#
#
#   지도학습 - 분류
#
#   - 미리 정의된 여러 클래스(정답 데이터의 갯수) 레이블 중 하나를 예측하는 것
#   - 속성 값을 입력, 클래스 값을 출력하는 모델
#   - 이진분류, 다중 분류
#
#   지도학습 - 회귀
#
#   - 연속적인 숫자를 예측하는 것
#   - 속성 값을 입력, 연속적인 실수 값을 출력으로 하는 모델
#   - 어떤 사람의 교육적인, 나이, 주거지를 바탕으로 연간 소득 예측 등
#   - 예측 값의 미묘한 차이가 크게 중요하지 않음
#
#
#   ### 비지도학습
#
#   - 데이터에 대한 Label이 없는 상태에서 컴퓨터를 학습시키는 방법
#   - 데이터의 숨겨진 특징, 구조, 패턴을 파악하는데 사용
#   - 클러스터링, 차원축소 등
#
#
#   ### 강화학습
#
#   - 지도학습과 비슷하지만 완전한 답(Label)을 제공하지 않음
#   -
#
#
#   ### 머신러닝 과정
#
#   1. Problem Identification(문제정의)
#   2. Data Collect(데이터 수집) - file, Database, Web Crawler, IoT 센서, Survey
#   3. Data Preprocessing(데이터 전처리) - 결측치, 이상치 처리 , 특성공학 : scaling(단위 변환) , Encoding(범주형 -> 수치형) , Binning(수치혀 -> 범주형), Transform(새로운 속성 추출)
#   4. EDA(탐색적 데이터분석) - 기술통계, 변수간 상관관계 , 시각화: pandas , matplotlib, seaborn ,  Feature Selection (사용할 특성 선택)
#   5. Model (선택), Hyper Parameter (조정) - 목정에 맞는 적절한 모델 선택 ex) knn, svm, Linear Regression ... / Hyper Parameter : model 의 성능을 개선하기 위해 사림이 직접 넣는 parameter
#   6. Training(학습) - model.fit(X_train(문제 데이터, Feature(독립변수)), Y_train(정답데이터, Label, 종속변수)) train 데이터와 test 데이터를 일정 비율로 나눔 , train데이터의 문제와 정답으로 모델 학습
#                     -  model.predict(X_test) : test 데이터의 문제를 넣고 정답을 예측
#                     ![image-5.png](attachment:image-5.png)
#   7. Evaluation(평가) -
#
#
# # 시각화
#
#   ![image-4.png](attachment:image-4.png)
