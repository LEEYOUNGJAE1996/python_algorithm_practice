# %% [markdown]
# # 데이터 시각화를 위한 라이브러리
#
# - scatter
# - pie
# - histogram
# - bar chart
#
#
#
# pyplot   /   pyblab

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
# line chart 그려보기
y = [2,4,6,8]
plt.plot(y)
plt.show()

# %%
# 데이터 x,y
x = [1,2,3,4]
y = [2,4,6,8]
plt.plot(x,y)
